# %% [markdown]
# # Predict Minutes Played in 2021-22 For Each Player

# %% [markdown]
# #### Objective: predict how many minutes each player in the NBA will have based on what their personal history is (age and minutes played in past seasons)

# %% [markdown]
# #### Things to consider: Rookies will not have any history and will need to be entered manually or based on prior rookies who were drafted in their range

# %%
import pandas as pd

# %%
# load CSV files I have back to the 2000-2001 seasons
season_2001 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2001.csv', encoding='utf-16')
season_2002 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2002.csv', encoding='utf-16')
season_2003 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2003.csv', encoding='utf-16')
season_2004 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2004.csv', encoding='utf-16')
season_2005 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2005.csv', encoding='utf-16')
season_2006 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2006.csv', encoding='utf-16')
season_2007 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2007.csv', encoding='utf-16')
season_2008 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2008.csv', encoding='utf-16')
season_2009 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2009.csv', encoding='utf-16')
season_2010 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2010.csv', encoding='utf-16')
season_2011 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2011.csv', encoding='utf-16')
season_2012 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2012.csv', encoding='utf-16')
season_2013 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2013.csv', encoding='utf-16')
season_2014 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2014.csv', encoding='utf-16')
season_2015 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2015.csv', encoding='utf-16')
season_2016 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2016.csv', encoding='utf-16')
season_2017 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2017.csv', encoding='utf-16')
season_2018 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2018.csv', encoding='utf-16')
season_2019 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2019.csv', encoding='utf-16')
season_2020 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2020.csv', encoding='utf-16')
season_2021 = pd.read_csv(r'C:\Users\Casey\Documents\GitHub\NBA\NBA Scrapers\bbref_player_totals_by_season\player_totals_scrape_2021.csv', encoding='utf-16')

# %%
# add the year/season to each of the files
season_2001['Season'] = 2001
season_2002['Season'] = 2002
season_2003['Season'] = 2003
season_2004['Season'] = 2004
season_2005['Season'] = 2005
season_2006['Season'] = 2006
season_2007['Season'] = 2007
season_2008['Season'] = 2008
season_2009['Season'] = 2009
season_2010['Season'] = 2010
season_2011['Season'] = 2011
season_2012['Season'] = 2012
season_2013['Season'] = 2013
season_2014['Season'] = 2014
season_2015['Season'] = 2015
season_2016['Season'] = 2016
season_2017['Season'] = 2017
season_2018['Season'] = 2018
season_2019['Season'] = 2019
season_2020['Season'] = 2020
season_2021['Season'] = 2021

# %%
# union all the files together
unioned_df = pd.concat([season_2001, season_2002, season_2003, season_2004, season_2005, season_2006, season_2007, season_2008, season_2009, 
season_2010, season_2011, season_2012, season_2013, season_2014, season_2015, season_2016, season_2017, season_2018, season_2019, season_2020, season_2021], ignore_index=True)

# %%
unioned_df.head()
# Out:
#                   Name Position  Age Team  games_played  games_started  \
# 0   Mahmoud Abdul-Rauf       PG   31  VAN            41             41
# 1    Tariq Abdul-Wahad       SG   26  DEN            29             29
# 2  Shareef Abdur-Rahim       SF   24  VAN            81             81
# 3       Cory Alexander       PG   27  ORL            26             26
# 4   Courtney Alexander       PG   23  TOT            65             65
#
#    minutes_played  field_goals  field_goals_attempted  field_goal_percentage  \
# 0             486          120                    246                  0.488
# 1             420           43                    111                  0.387
# 2            3241          604                   1280                  0.472
# 3             227           18                     56                  0.321
# 4            1382          239                    573                  0.417
#
#     ...    offensive_rebs  defensive_rebs  total_rebs  assists  steals  \
# 0   ...                 5              20          25       76       9
# 1   ...                14              45          59       22      14
# 2   ...               175             560         735      250      90
# 3   ...                 0              25          25       36      16
# 4   ...                42             101         143       62      45
#
#    blocks  turnovers  personal_fouls  points_scored  Season
# 0       1         26              50            266    2001
# 1      13         34              54            111    2001
# 2      77        231             238           1663    2001
# 3       0         25              29             52    2001
# 4       5         75             139            618    2001
#
# [5 rows x 30 columns]

# %%
unioned_df.tail()
# Out:
#                  Name Position  Age Team  games_played  games_started  \
# 12431    Delon Wright       PG   28  SAC            27             27
# 12432  Thaddeus Young       PF   32  CHI            68             68
# 12433      Trae Young       PG   22  ATL            63             63
# 12434     Cody Zeller        C   28  CHO            48             48
# 12435     Ivica Zubac        C   23  LAC            72             72
#
#        minutes_played  field_goals  field_goals_attempted  \
# 12431             696          104                    225
# 12432            1652          370                    662
# 12433            2125          487                   1112
# 12434            1005          181                    324
# 12435            1609          257                    394
#
#        field_goal_percentage   ...    offensive_rebs  defensive_rebs  \
# 12431                  0.462   ...                28              77
# 12432                  0.559   ...               168             255
# 12433                  0.438   ...                38             207
# 12434                  0.559   ...               119             209
# 12435                  0.652   ...               189             330
#
#        total_rebs  assists  steals  blocks  turnovers  personal_fouls  \
# 12431         105       97      43      11         35              30
# 12432         423      291      74      40        137             152
# 12433         245      594      53      12        261             111
# 12434         328       86      27      17         51             121
# 12435         519       90      24      62         81             187
#
#        points_scored  Season
# 12431            271    2021
# 12432            823    2021
# 12433           1594    2021
# 12434            451    2021
# 12435            650    2021
#
# [5 rows x 30 columns]

# %%
# limit to the columns we need for minute projections
keeper_cols = ['Name', 'Age', 'minutes_played', 'Season']
minutes_df = unioned_df[keeper_cols]

# %%
minutes_df = minutes_df.sort_values(by=['Name', 'Season'])

# %%
minutes_df.head()
# Out:
#               Name  Age  minutes_played  Season
# 181     A.C. Green   37            1411    2001
# 184    A.J. Guyton   22             630    2001
# 716    A.J. Guyton   23             607    2002
# 1203   A.J. Guyton   24               9    2003
# 9321  A.J. Hammons   24             163    2017

# %%
# check an example to see if everything looks OK
minutes_df[minutes_df['Name'] == 'Kobe Bryant']
# Out:
#              Name  Age  minutes_played  Season
# 61    Kobe Bryant   22            2783    2001
# 610   Kobe Bryant   23            3063    2002
# 1101  Kobe Bryant   24            3401    2003
# 1606  Kobe Bryant   25            2447    2004
# 2188  Kobe Bryant   26            2689    2005
# 2770  Kobe Bryant   27            3277    2006
# 3322  Kobe Bryant   28            3140    2007
# 3851  Kobe Bryant   29            3192    2008
# 4453  Kobe Bryant   30            2960    2009
# 5030  Kobe Bryant   31            2835    2010
# 5623  Kobe Bryant   32            2779    2011
# 6218  Kobe Bryant   33            2232    2012
# 6778  Kobe Bryant   34            3013    2013
# 7368  Kobe Bryant   35             177    2014
# 7963  Kobe Bryant   36            1207    2015
# 8604  Kobe Bryant   37            1863    2016

# %%
# get most recent season played for each player
first_last_seasons = minutes_df.groupby('Name').agg({'Season':['min', 'max']}).reset_index()

# %%
first_last_seasons.head()
# Out:
#            Name Season
#                    min   max
# 0    A.C. Green   2001  2001
# 1   A.J. Guyton   2001  2003
# 2  A.J. Hammons   2017  2017
# 3    A.J. Price   2010  2015
# 4  Aaron Brooks   2008  2018

# %%
first_last_seasons.columns.droplevel(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-e11d456eb713> in <module>()
# ----> 1 first_last_seasons.droplevel(0)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'droplevel'

# %%
first_last_seasons.rename(columns={first_last_seasons.columns[1]: 'Name'}, inplace=True)
first_last_seasons.rename(columns={first_last_seasons.columns[2]: 'first_season_in_data'}, inplace=True)
first_last_seasons.rename(columns={first_last_seasons.columns[3]: 'most_recent_season'}, inplace=True)

first_last_seasons.head()
